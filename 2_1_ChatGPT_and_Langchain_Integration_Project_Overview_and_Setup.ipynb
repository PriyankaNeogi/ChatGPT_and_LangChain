# %% [markdown]
# #### Installation Required -
#
# ![WhatsApp Image 2024-12-18 at 7.19.58 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# - we're gonna need Python 3 installed.
# - install a package called OpenAI.
# -  need to install LangChain.
# - We're gonna install both these using pip, package manager.
#
# need a OpenAI API key :
#
# - so we can access ChatGPT programmatically.
#
# - To generate this key and make use of it,
#
#
# `The process of generating that key changes every now and then,
#  and it's just a lot easier to keep it up to date if it's in text format.`
#
# - we need a code editor and a terminal, using `VSCode`.
# - you're gonna need a terminal as well.

# %% [markdown]
# 1. Create a directory
# 2. Open the folder inside the VScode.
# 3. Open the terminal inside the Vscode folder.
#
# More details - https://medium.com/@priyanka_neogi/comprehensive-guide-setting-up-vs-code-for-python-development-c08feb0bb310

# %% [markdown]
# ![Screenshot 2024-12-18 at 10.10.24 PM.png](data:image/png;base64,...)

# %% [markdown]
# To activate the environment inside the folder (if the virtual environment is already created)-
# - select - python base interpreter
# - On terminal write -> conda activate "python /Users/priyankaneogi/Desktop/pycode/venv" (take the path by right clicking on folder's venv)
#
#
# To execute the py file -
# - write the code in the .py file
# - save the .py file
# - on terminal write  -> 'python /Users/priyankaneogi/Desktop/pycode/demo.py' to execute the python file

# %% [markdown]
# Anaconda Documentation - (can go through the entire docmentation to know more)
# - it contains all the packages
#   - it will provide the base environment
#   - it will provide support to different IDE's
#
# - read about conda commands

# %% [markdown]
# #### Pip - is a package manager.
# If we are using pip then what is the repository from where the pacages are taken? where is it stored?
# - PYPI - is a repository of software for python programming language.
#   - can cretae an account at PYPI site
#     - new packages trying to install like flask, numpy, mongodb etc (it is available inside the repository of PYPI)
#
#
# -  pip commands
# - pip command cheetsheats
